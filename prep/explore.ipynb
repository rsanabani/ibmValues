# %%
import pandas as pd

df = pd.read_excel('OriginalTweets.xlsx')
len(df)
# Out:
# 9621

# %%
df.head(300).to_excel('Top300Tweets.xlsx', index=False)

# %%
df = pd.read_excel('Top300Tweets.xlsx')
df
# Out:
#     original_author                                     original_tweet  \
# 0         assisterr  GM Agents! We've all been waiting for this mom...
# 1          immorriv  Terminal of Truth 2.0: The "True" AI Meme Mani...
# 2      OpenGradient  We are excited to announce that OpenGradient h...
# 3        TimshelXYZ  {action: mint, rune: BITCOINPENNIES, AI: @scri...
# 4     BrianRoemmele  Comparing the rather expensive OpenAI Sora to ...
# ..              ...                                                ...
# 295        samsja19  Intellect 1 is out. It's a 10B model trained a...
# 296     RedactedRes  The awakening is near and it's time to unveil ...
# 297     HeidyKhlaaf  A crucial paper on the open-source discourse t...
# 298  ScottAdamsSays  Solving murders is going to get a lot harder. ...
# 299         Mintify  Our friends at @0n1Force have been cooking QT ...
#
#      Page_Rank  Rank        topic     author_display_name  \
# ...

# %%
df
# Out:
#      original_author                                     original_tweet  \
# 0          assisterr  GM Agents! We've all been waiting for this mom...
# 1           immorriv  Terminal of Truth 2.0: The "True" AI Meme Mani...
# 2       OpenGradient  We are excited to announce that OpenGradient h...
# 3         TimshelXYZ  {action: mint, rune: BITCOINPENNIES, AI: @scri...
# 4      BrianRoemmele  Comparing the rather expensive OpenAI Sora to ...
# ...              ...                                                ...
# 9616        zywu_hku  Cool! QT @jamesmurdza: Introducing fully open ...
# 9617           a16zo  framework upgrade continues, dev school integr...
# 9618       _xxravven  Is NVIDIA playing catch up and if so is hardwa...
# 9619      aaronjmars  fork langchain seazon QT @jyu_eth: We're build...
# 9620            a2d2  This is a horrifying(ly simple) example of a s...
#
#       Page_Rank    Rank        topic     author_display_name  \
# ...
